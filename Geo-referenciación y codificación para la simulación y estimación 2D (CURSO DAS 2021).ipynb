# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

df_simulacion = pd.read_csv("C:/Users/nubem/Desktop/Nube Minera 2021/DEMOSTRACIÓN_ALGORITMOS_SGEMS_V2_2021/23. Simulación Secuencial de Indicadores/simulaciones_2d_roca.csv", sep=";")
df_estimacion = pd.read_csv("C:/Users/nubem/Desktop/Nube Minera 2021/DEMOSTRACIÓN_ALGORITMOS_SGEMS_V2_2021/23. Simulación Secuencial de Indicadores/estimacion_2d_kriging_indicadores.csv", sep=";")
mine = df_estimacion.idxmax(axis=1)
df_estimacion["Roca_est"] = mine
df_estimacion.head()
# Out:
#       RocaA     RocaB Roca_est
# 0  0.813947  0.186053    RocaA
# 1  0.819996  0.180004    RocaA
# 2  0.826136  0.173864    RocaA
# 3  0.826723  0.173277    RocaA
# 4  0.832975  0.167025    RocaA

# %%
grid_x = np.linspace(0,1000, num=100, endpoint=False) #Coord. de origen x, coord. de termino x, nª de celdas x.
grid_y = np.linspace(0,1000, num=100, endpoint=False) #Coord. de origen y, coord. de termino y, nª de celdas y.

#En este caso la matriz es de 100 x 100 celdas.

gy = np.array(grid_y) #conversión a un array de numpy 
gx = np.array(grid_x) #conversión a un array de numpy 

yg, xg = np.meshgrid(grid_x, grid_y, indexing='ij') #Creación de la grilla (intersecciones en yg; xg)

x_g = xg.ravel() #aplanamiento de xg
y_g = yg.ravel() #aplanamiento de yg

# %%
d = {'Este [X]': x_g, 'Norte [Y]': y_g} #Columnas con coordenadas X e Y.
df = pd.DataFrame(data=d) #Creación del dataframe 
       
df["Roca"] = df_estimacion["Roca_est"] #Traspaso de la columna VA al nuevo DataFrame.
df["Roca_simulada"] = df_simulacion["selection"]
df.head()
# Out:
#    Este [X]  Norte [Y]   Roca Roca_simulada
# 0       0.0        0.0  RocaA         RocaA
# 1      10.0        0.0  RocaA         RocaA
# 2      20.0        0.0  RocaA         RocaA
# 3      30.0        0.0  RocaA         RocaA
# 4      40.0        0.0  RocaA         RocaA

# %%
fig = px.scatter(df, x="Este [X]", y="Norte [Y]", color="Roca", color_discrete_sequence=["gray", "yellow"])
fig.update_traces(marker=dict(size=7,symbol = 'square'),
                  selector=dict(mode='markers'))   

fig.update_layout(
    autosize=False,
    width=700,
    height=700,)

fig.show()
# Out:
# <div>                            <div id="2ca76d3c-0913-4f30-b4b4-318f31151d29" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ca76d3c-0913-4f30-b4b4-318f31151d29")) {                    Plotly.newPlot(                        "2ca76d3c-0913-4f30-b4b4-318f31151d29",                        [{"hovertemplate": "Roca=RocaA<br>Este [X]=%{x}<br>Norte [Y]=%{y}<extra></extra>", "legendgroup": "RocaA", "marker": {"color": "gray", "size": 7, "symbol": "square"}, "mode": "markers", "name": "RocaA", "showlegend": true, "type": "scattergl", "x": [0.0, 10.0, 20.0, 30.0, 40.0, 50.0, 60.0, 70.0, 80.0, 90.0, 100.0, 110.0, 120.0, 130.0, 140.0, 150.0, 160.0, 170.0, 180.0, 190.0, 200.0, 210.0, 220.0, 230.0, 240.0, 250.0, 260.0, 270.0, 280.0, 290.0, 300.0, 310.0, 320.
# ...

# %%
fig = px.scatter(df, x="Este [X]", y="Norte [Y]", color="Roca_simulada", color_discrete_sequence=["gray", "yellow"])
fig.update_traces(marker=dict(size=7,symbol = 'square'),
                  selector=dict(mode='markers'))   

fig.update_layout(
    autosize=False,
    width=700,
    height=700,)

fig.show()
# Out:
# <div>                            <div id="b6565245-5a16-4796-baa0-8a5161d5dd7e" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b6565245-5a16-4796-baa0-8a5161d5dd7e")) {                    Plotly.newPlot(                        "b6565245-5a16-4796-baa0-8a5161d5dd7e",                        [{"hovertemplate": "Roca_simulada=RocaA<br>Este [X]=%{x}<br>Norte [Y]=%{y}<extra></extra>", "legendgroup": "RocaA", "marker": {"color": "gray", "size": 7, "symbol": "square"}, "mode": "markers", "name": "RocaA", "showlegend": true, "type": "scattergl", "x": [0.0, 10.0, 20.0, 30.0, 40.0, 50.0, 60.0, 70.0, 80.0, 90.0, 100.0, 110.0, 120.0, 130.0, 140.0, 150.0, 160.0, 170.0, 180.0, 190.0, 200.0, 210.0, 220.0, 230.0, 240.0, 250.0, 260.0, 270.0, 280.0, 290.0, 300.0, 31
# ...

# %%
df.to_csv("C:/Users/nubem/Desktop/Nube Minera 2021/DEMOSTRACIÓN_ALGORITMOS_SGEMS_V2_2021/23. Simulación Secuencial de Indicadores/modelo_de_rocas_2d.csv.csv")
